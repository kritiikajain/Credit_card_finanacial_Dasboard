# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('credit_card.csv')

# %%
column_name = df.columns
print(column_name)
# Out:
# Index(['Client_Num', 'Card_Category', 'Annual_Fees', 'Activation_30_Days',
#        'Customer_Acq_Cost', 'Week_Start_Date', 'Week_Num', 'Qtr',
#        'current_year', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Total_Trans_Amt', 'Total_Trans_Vol', 'Avg_Utilization_Ratio',
#        'Use Chip', 'Exp Type', 'Interest_Earned', 'Delinquent_Acc'],
#       dtype='object')

# %%
# Function to convert date format
def convert_date_format(date_str):
    return pd.to_datetime(date_str, format='%d-%m-%Y').strftime('%d/%m/%Y')

# Apply the function to the date column
df['Week_Start_Date'] = df['Week_Start_Date'].apply(convert_date_format)

# Save the DataFrame back to a CSV file
df.to_csv('credit_card_formatted.csv', index=False)

# %%
df['Week_Start_Date'].dtype
# Out:
# dtype('O')

# %%
df.dtypes
# Out:
# Client_Num                 int64
# Card_Category             object
# Annual_Fees                int64
# Activation_30_Days         int64
# Customer_Acq_Cost          int64
# Week_Start_Date           object
# Week_Num                  object
# Qtr                       object
# current_year               int64
# Credit_Limit             float64
# Total_Revolving_Bal        int64
# Total_Trans_Amt            int64
# Total_Trans_Vol            int64
# Avg_Utilization_Ratio    float64
# Use Chip                  object
# Exp Type                  object
# Interest_Earned          float64
# Delinquent_Acc             int64
# dtype: object

# %%
df['Week_Start_Date'].to_date
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df['Week_Start_Date'].to_date
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'to_date'

# %%
df['Week_Start_Date'] = pd.to_datetime(df['Week_Start_Date'], format='%d/%m/%Y')

# %%
df.dtypes
# Out:
# Client_Num                        int64
# Card_Category                    object
# Annual_Fees                       int64
# Activation_30_Days                int64
# Customer_Acq_Cost                 int64
# Week_Start_Date          datetime64[ns]
# Week_Num                         object
# Qtr                              object
# current_year                      int64
# Credit_Limit                    float64
# Total_Revolving_Bal               int64
# Total_Trans_Amt                   int64
# Total_Trans_Vol                   int64
# Avg_Utilization_Ratio           float64
# Use Chip                         object
# Exp Type                         object
# Interest_Earned                 float64
# Delinquent_Acc                    int64
# dtype: object

# %%
df.to_csv('credit_card_formatted.csv', index=False)

# %%
df1 = pd.read_csv("D:\cc_add.csv")

# %%
df1
# Out:
#      Client_Num Card_Category  Annual_Fees  Activation_30_Days  \
# 0     963607849          Blue          300                   1
# 1     932954954          Blue          175                   1
# 2     961650885          Blue          195                   0
# 3     917695309          Blue          495                   1
# 4     957309271          Blue          100                   0
# ..          ...           ...          ...                 ...
# 180   964474458          Blue          100                   0
# 181   962482385        Silver          100                   1
# 182   919695363          Blue          475                   1
# 183   931822111          Blue          275                   0
# 184   925168075          Blue          245                   1
#
#      Customer_Acq_Cost Week_Start_Date Week_Num Qtr  current_year  \
# 0                  108      31-12-2023  Week-53  Q4          2023
# 1                   96      31-12-2023  Week-53  Q4          2023
# ...

# %%
df1.dtypes
# Out:
# Client_Num                 int64
# Card_Category             object
# Annual_Fees                int64
# Activation_30_Days         int64
# Customer_Acq_Cost          int64
# Week_Start_Date           object
# Week_Num                  object
# Qtr                       object
# current_year               int64
# Credit_Limit             float64
# Total_Revolving_Bal        int64
# Total_Trans_Amt            int64
# Total_Trans_Ct             int64
# Avg_Utilization_Ratio    float64
# Use Chip                  object
# Exp Type                  object
# Interest_Earned          float64
# Delinquent_Acc             int64
# dtype: object

# %%
df1['Week_Start_Date'] = pd.to_datetime(df1['Week_Start_Date'], format='%d-%m-%Y')

# %%
df1.dtypes
# Out:
# Client_Num                        int64
# Card_Category                    object
# Annual_Fees                       int64
# Activation_30_Days                int64
# Customer_Acq_Cost                 int64
# Week_Start_Date          datetime64[ns]
# Week_Num                         object
# Qtr                              object
# current_year                      int64
# Credit_Limit                    float64
# Total_Revolving_Bal               int64
# Total_Trans_Amt                   int64
# Total_Trans_Ct                    int64
# Avg_Utilization_Ratio           float64
# Use Chip                         object
# Exp Type                         object
# Interest_Earned                 float64
# Delinquent_Acc                    int64
# dtype: object

# %%
df1.to_csv('D:\cc_add_formatted.csv', index=False)
